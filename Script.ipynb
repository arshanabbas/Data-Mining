# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
csv_path = r"F:\Pomodoro\Work\TIME\Script\Data Mining\Data-Mining\train.csv"
df = pd.read_csv(csv_path)  
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.hist(figsize=(10,10))
plt.show()

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(df, test_size=0.3, random_state=0, stratify = df['Survived'])
print(train_set)
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 231          232         0       3              Larsson, Mr. Bengt Edvin
# 836          837         0       3                      Pasic, Mr. Jakob
# 639          640         0       3            Thorneycroft, Mr. Percival
# 389          390         1       2                 Lehmann, Miss. Bertha
# 597          598         0       3                   Johnson, Mr. Alfred
# ..           ...       ...     ...                                   ...
# 131          132         0       3        Coelho, Mr. Domingos Fernandeo
# 490          491         0       3  Hagland, Mr. Konrad Mathias Reiersen
# 838          839         1       3                       Chip, Mr. Chang
# 48            49         0       3                   Samaan, Mr. Youssef
# 80            81         0       3                  Waelens, Mr. Achille
#
#         Sex        Age  SibSp  Parch              Ticket     Fare Cabin  \
# ...

# %%
train_set_path = r"F:\Pomodoro\Work\TIME\Script\Data Mining\Data-Mining\train.csv"
train_set = pd.read_csv(train_set_path)
numeric_data = train_set.select_dtypes(include=['number'])
corr_matrix = numeric_data.corr()
plt.figure(figsize=(7, 5))
sns.heatmap(corr_matrix, annot=True, vmin=-1, vmax=1)
plt.title("Korrelationen im Titanic-Datensatz")
plt.show()

# %%
df.loc[df.Sex =='male', 'Sex']=0
df.loc[df.Sex =='female', 'Sex']=1

# %%
X_train=train_set[['Sex', 'Pclass']]
X_train.info()
y_train=train_set[['Survived']]

X_test=test_set[['Sex', 'Pclass']]
X_test.info()
y_test=test_set[['Survived']]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 623 entries, 231 to 80
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sex     623 non-null    object
#  1   Pclass  623 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 14.6+ KB
# <class 'pandas.core.frame.DataFrame'>
# Index: 268 entries, 421 to 607
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sex     268 non-null    object
#  1   Pclass  268 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 6.3+ KB

# %%
from sklearn.tree import DecisionTreeClassifier
tree_clf = DecisionTreeClassifier(max_depth = 2)
tree_clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_74828\2211746027.py in ?()
#       1 from sklearn.tree import DecisionTreeClassifier
#       2 tree_clf = DecisionTreeClassifier(max_depth = 2)
# ----> 3 tree_clf.fit(X_train, y_train)
#
# c:\Users\arsha\anaconda3\envs\AbbasThesis\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\arsha\anaconda3\envs\AbbasThesis\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1005         self : DecisionTreeClassifier
#    1006             Fitted estimator.
#    1007         """
# ...

# %%
from sklearn import tree
tree.plot_tree(tree_clf, feature_names = X_train.columns, class_names=['not-Survived', 'Survived'], filled=True);

# %%
print(tree_clf.score(X_train, y_train))
print(tree_clf.score(X_test, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_74828\949523270.py in ?()
# ----> 1 print(tree_clf.score(X_train, y_train))
#       2 print(tree_clf.score(X_test, y_test))
#
# c:\Users\arsha\anaconda3\envs\AbbasThesis\Lib\site-packages\sklearn\base.py in ?(self, X, y, sample_weight)
#     760             Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     761         """
#     762         from .metrics import accuracy_score
#     763
# --> 764         return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# c:\Users\arsha\anaconda3\envs\AbbasThesis\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, check_input)
#     525         y : array-like of shape (n_samples,) or (n_samples, n_outputs)
#     526             The predicted classes, or the predict values.
#     527         """
#     528         check_is_fitted(self)
# ...

# %%
train_set, test_set = train_test_split(df, test_size=0.3, random_state=0, stratify = df['Survived'])
X_train=train_set[['Sex', 'Pclass', 'Parch', 'Age', 'Fare']]
y_train=train_set[['Survived']]

X_test=test_set[['Sex', 'Pclass', 'Parch', 'Age', 'Fare']]
y_test=test_set[['Survived']]

# %%
tree_clf = DecisionTreeClassifier(max_depth = 3)  
tree_clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_74828\2630645292.py in ?()
#       1 tree_clf = DecisionTreeClassifier(max_depth = 3)
# ----> 2 tree_clf.fit(X_train, y_train)
#
# c:\Users\arsha\anaconda3\envs\AbbasThesis\Lib\site-packages\sklearn\base.py in ?(estimator, *args, **kwargs)
#    1469                 skip_parameter_validation=(
#    1470                     prefer_skip_nested_validation or global_skip_validation
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#
# c:\Users\arsha\anaconda3\envs\AbbasThesis\Lib\site-packages\sklearn\tree\_classes.py in ?(self, X, y, sample_weight, check_input)
#    1005         self : DecisionTreeClassifier
#    1006             Fitted estimator.
#    1007         """
#    1008
# -> 1009         super()._fit(
# ...
